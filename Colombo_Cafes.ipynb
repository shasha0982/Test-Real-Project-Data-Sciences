# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-cc75f495-624a-47f1-b921-390e39265034" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cc75f495-624a-47f1-b921-390e39265034">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
colombo_cafes = pd.read_csv('colombo_cafes.csv')

# %%
# Check number of unique cafe titles

# %%
num_unique_titles = colombo_cafes['title'].nunique()
num_unique_titles
# Out:
# 338

# %%
# Check the frequency counts of cafe titles

# %%
title_counts = colombo_cafes['title'].value_counts()
title_counts
# Out:
# Cafe nine                     2
# Cafe Celo09                   2
# The Coffee Bean & Tea Leaf    2
# Bun Break                     2
# Everyday Bakery & Cafe        2
#                              ..
# Spice Cafe & Bakers           1
# PJ's Cafe                     1
# Colombo Foods                 1
# Cafe Leafy                    1
# Busy Bean Cafe                1
# Name: title, Length: 338, dtype: int64

# %%
# define statistics of colombo cafes

# %%
colombo_cafes.head()
# Out:
#                         title  totalScore  reviewsCount  \
# 0      Coco Cafe- Street Star    4.600000            11
# 1                 Cafe Celo09    4.258885             0
# 2  Cafe 1959 by Raux Brothers    4.400000           248
# 3                    Cafe Lab    2.800000             8
# 4    The Nook Cakery and Cafe    4.900000            34
#
#                     street     city countryCode  \
# 0  VVQ5+326, Elfindale Ave  Colombo          LK
# 1                 VVRC+8M5  Colombo          LK
# 2             746 Galle Rd  Colombo          LK
# 3                      NaN  Colombo          LK
# 4    29 Visakha Private Rd  Colombo          LK
#
#                                              website            phone  \
# 0  https://www.facebook.com/cococafe.lk?mibextid=...  +94 76 777 2225
# 1                                                NaN              NaN
# 2  https://cafe-1959-by-raux-brothers.business.si...  +94 112 590 520
# ...

# %%
# Rate total_score (customer ratings)

# %%
# @title totalScore

from matplotlib import pyplot as plt
colombo_cafes['totalScore'].plot(kind='hist', bins=20, title='totalScore')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# reviewsCount - The number of reviews for each café, providing insights into customer engagement

# %%
# @title reviewsCount

from matplotlib import pyplot as plt
colombo_cafes['reviewsCount'].plot(kind='line', figsize=(8, 4), title='reviewsCount')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# street, city, countryCode: These columns offer detailed location information for each café, enabling geographic analyses and mapping.

# %%
unique_streets = colombo_cafes['street'].value_counts(dropna=False)
unique_streets
# Out:
# NaN                                    3
# 318 Torrington Ave                     2
# 8 Stratford Ave                        2
# 30 Prof Stanley Wijesundera Mawatha    2
# 137 Sir James Pieris Mawatha           2
#                                       ..
# 30 Hyde Park Corner                    1
# City Center                            1
# 7 Park Rd                              1
# No. 10 R. A. De Mel Mawatha            1
# Race Course Ave                        1
# Name: street, Length: 332, dtype: int64

# %%
colombo_cafes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 343 entries, 0 to 342
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   title         343 non-null    object
#  1   totalScore    343 non-null    float64
#  2   reviewsCount  343 non-null    int64
#  3   street        340 non-null    object
#  4   city          343 non-null    object
#  5   countryCode   343 non-null    object
#  6   website       97 non-null     object
#  7   phone         242 non-null    object
#  8   categoryName  343 non-null    object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 24.2+ KB

# %%
colombo_cafes.describe()
# Out:
#        totalScore  reviewsCount
# count  343.000000    343.000000
# mean     4.258885    191.288630
# std      0.600572    482.369615
# min      1.000000      0.000000
# 25%      4.100000      1.000000
# 50%      4.258885     10.000000
# 75%      4.600000     98.000000
# max      5.000000   3505.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['totalScore'].plot(kind='hist', bins=20, title='totalScore')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['reviewsCount'].plot(kind='hist', bins=20, title='reviewsCount')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# ...

# %%
# totalscore - The average customer rating for each café, on a scale from 1 to 5

# %%
_df_0['totalScore'].plot(kind='hist', bins=20, title='totalScore')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
#reviewscount

# %%
_df_4['reviewsCount'].plot(kind='line', figsize=(8, 4), title='reviewsCount')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# totalscore vs reviewscount

# %%
_df_2.plot(kind='scatter', x='totalScore', y='reviewsCount', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# categoryName: The classification of the establishment (e.g., Café, Coffee Shop), useful for segmenting and analyzing the data.

# %%
colombo_cafes['categoryName'].value_counts()
# Out:
# Cafe                               162
# Coffee shop                         73
# Restaurant                          57
# Bakery                               7
# Vegetarian restaurant                5
# Tea house                            3
# Fast food restaurant                 3
# Sri Lankan restaurant                2
# Takeout Restaurant                   2
# Pastry shop                          2
# Asian restaurant                     2
# Ice cream shop                       2
# Indian restaurant                    1
# North Eastern Indian restaurant      1
# Cake shop                            1
# Authentic Japanese restaurant        1
# Bar                                  1
# Dessert shop                         1
# Fusion restaurant                    1
# Grocery store                        1
# Print shop                           1
# Art cafe                             1
# Pizza restaurant                     1
# Game store                           1
# ...
